# %%
#!/usr/bin/env python
# coding: utf-8

# In[6]:


import pandas as pd 

import requests   
from bs4 import BeautifulSoup


#[CODE 1]
#네이버 금융 국내증시 상위100의 기업 이름과 url 크롤링
def get_top100(top100_url, top100_name):
    url = 'https://finance.naver.com/sise/sise_quant.nhn'
    result = requests.get(url)
    html = BeautifulSoup(result.content, 'html.parser')

    top100 = html.find_all('a', {'class':'tltle'})

    for i in range(100):
        url = 'https://finance.naver.com' + top100[i]['href']    
        top100_url.append(url)
    
        company_name = top100[i].string    
        top100_name.append(company_name)

    return (top100_url, top100_name)


#[CODE 2] 검색할 기업 입력받기
def get_company(top100_name):
    company_name = input('주가를 검색할 기업이름을 입력하세요: ')

    for i in range(101):
        if i == 100:
            return(100)
        if company_name == top100_name[i]:            
            return(i)            

#[CODE 3]
# company_url에 대한 기업 주식 정보 페이지 크롤링
def get_company_stockPage(company_url):    
    result = requests.get(company_url)
    company_stockPage = BeautifulSoup(result.content, "html.parser")
    return company_stockPage


#[CODE 4] 
# 기업의 현재 주가 데이터 크롤링
def get_price(company_url):
    company_stockPage = get_company_stockPage(company_url) #[CODE 3]
    no_today = company_stockPage.find("p", {"class": "no_today"})
    blind = no_today.find("span", {"class": "blind"})
    now_price = blind.text
    return now_price


#[CODE 0]
def main():
    top100_url=[]
    top100_name = []

    top100_url, top100_name = get_top100(top100_url, top100_name) #[CODE 1]

    print("< 현재 네이버 금융 국내 코스피 상위100 기업 목록 >")
    print(top100_name)
    print('')

    company = int(get_company(top100_name))  #[CODE 2]
    if company == 100:
        print("입력한 기업은 상위100 목록에 없습니다.")        
    else :        
        now_price = get_price(top100_url[company]) #[CODE 4]
        print('%s 기업의 현재 주가는 %s 입니다' % (top100_name[company], now_price))


if __name__ == '__main__':
     main()
# Out:
# < 현재 네이버 금융 국내 코스피 상위100 기업 목록 >
# ['베트남개발1', 'KODEX 200선물인버스2X', '대한전선', 'KODEX 인버스', 'KODEX 레버리지', '에이프로젠', 'KODEX 코스닥150선물인버스', '남성', 'KODEX 코스닥150레버리지', 'SG글로벌', '금양', '인디에프', '신한 인버스 2X 천연가스 선물 ETN', 'TRUE 인버스 2X 천연가스 선물 ETN(H)', 'KODEX 미국달러선물인버스2X', '카카오뱅크', '삼성전자', '현대두산인프라코어', '한신기계', '삼성 인버스 2X WTI원유 선물 ETN', '이수화학', '인바이오젠', '삼성 인버스 2X 코스닥150 선물 ETN', '두산에너빌리티', '한국전력', 'KODEX 200', 'TIGER 200선물인버스2X', '카카오', 'KODEX 코스닥150', '범양건영', '이엔플러스', '세원이앤씨', '카카오페이', '유니온머티리얼', '도화엔지니어링', '남선알미늄', 'KODEX WTI원유선물인버스(H)', 'KODEX 미국나스닥100레버리지(합성 H)', '그린케미칼', '형지엘리트', '한화솔루션', 'TIGER 미국S&P500', 'TIGER 차이나전기차SOLACTIVE', 'TYM', 'QV 인버스 레버리지 WTI원유 선물 ETN(H)', '팬오션', '성안', '한미글로벌', '신성이엔지', '케이비아이동국실업', '삼부토건', '조일알미늄', '미래에셋 인버스 2X 코스피200 선물 ETN', 'STX중공업', '다스코', '알루코', '대우건설', '삼성중공업', 'SK하이닉스', 'NAVER', 'KODEX 2차전지산업', '수산중공업', '태경비케이', '우진', '삼성전기', '인팩', 'TIGER 인버스', 'TRUE 인버스 2X 코스닥 150 선물 ETN', '한솔홈데코', '일성건설', 'SH에너지화학', '메리츠증권', 'HANARO 200선물인버스', 'SG세계물산', 'LG디스플레이', 'KB 인버스 2X KOSDAQ 150 선물 ETN', '자화전자', 'GS글로벌', 'TIGER 원유선물인버스(H)', '기아', '서울식품', '신한지주', '쌍방울', '현대약품', '한전산업', '두산퓨얼셀', 'TIGER 차이나항셍테크', 'KODEX 자동차', '코오롱글로벌', 'TIGER 미국테크TOP10 INDXX', 'KB금융', 'HMM', '혜인', '후성', 'KT', 'TRUE 인버스 2X 나스닥 100 ETN', '한화생명', '이구산업', 'ACE 글로벌브랜드TOP10블룸버그', 'BNK금융지주']
#
# 주가를 검색할 기업이름을 입력하세요: 인디에프
# 인디에프 기업의 현재 주가는 1,490 입니다
